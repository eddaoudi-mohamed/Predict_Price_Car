# %%
import joblib
import numpy as np
import pandas as pd

# %%
preprocessor  = joblib.load('../Models/preprocessor.pkl')
model = joblib.load('../Models/random_forest_model.pkl')

# %%
new_car = pd.DataFrame([{
    'year': 2020,
    'puissance': 6,
    'kilometrage': 105000 , 
    'type_boit': 'automatique',
    'type_carburant': 'diesel',
    'model': 'clio',
    'marke': 'renault',
    'city': 'casablanca',
    'premiere_main': 0,
    'Nombre_doors': 5,
}])

# Transform
X_transformed = preprocessor.transform(new_car).toarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5480\1823638753.py in ?()
#      11     'Nombre_doors': 5,
#      12 }])
#      13
#      14 # Transform
# ---> 15 X_transformed = preprocessor.transform(new_car).toarray()
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\sklearn\compose\_column_transformer.py in ?(self, X, **params)
#    1097             routed_params = process_routing(self, "transform", **params)
#    1098         else:
#    1099             routed_params = self._get_empty_routing()
#    1100
# -> 1101         Xs = self._call_func_on_transformers(
#    1102             X,
#    1103             None,
#    1104             _transform_one,
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\sklearn\compose\_column_transformer.py in ?(self, X, y, func, column_as_labels, routed_params)
#     912         except ValueError as e:
#     913             if "Expected 2D array, got 1D array instead" in str(e):
#     914                 raise ValueError(_ERR_MSG_1DCOLUMN) from e
#     915             else:
# --> 916                 raise
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\sklearn\utils\parallel.py in ?(self, iterable)
#      73         iterable_with_config = (
#      74             (_with_config(delayed_func, config), args, kwargs)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\joblib\parallel.py in ?(self, iterable)
#    1914             # If n_jobs==1, run the computation sequentially and return
#    1915             # immediately to avoid overheads.
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#    1921         # call is interrupted early and that the same instance is immediately
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\joblib\parallel.py in ?(self, iterable)
#    1857         finally:
#    1858             self.print_progress()
#    1859             self._running = False
#    1860             self._iterating = False
# -> 1861             self._original_iterator = None
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\sklearn\utils\parallel.py in ?(self, *args, **kwargs)
#     135                 UserWarning,
#     136             )
#     137             config = {}
#     138         with config_context(**config):
# --> 139             return self.function(*args, **kwargs)
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\sklearn\pipeline.py in ?(transformer, X, y, weight, params)
#    1527         Parameters to be passed to the transformer's ``transform`` method.
#    1528
#    1529         This should be of the form ``process_routing()["step_name"]``.
#    1530     """
# -> 1531     res = transformer.transform(X, **params.transform)
#    1532     # if we have a weight for this transformer, multiply output
#    1533     if weight is None:
#    1534         return res
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\sklearn\pipeline.py in ?(self, X, **params)
#    1088             # enable_metadata_routing=True
#    1089             routed_params = process_routing(self, "transform", **params)
#    1090             Xt = X
#    1091             for _, name, transform in self._iter():
# -> 1092                 Xt = transform.transform(Xt, **routed_params[name].transform)
#    1093             return Xt
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, copy)
#    1058         """
#    1059         check_is_fitted(self)
#    1060
#    1061         copy = copy if copy is not None else self.copy
# -> 1062         X = validate_data(
#    1063             self,
#    1064             X,
#    1065             reset=False,
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2940             out = y
#    2941         else:
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#    2947     else:
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# c:\Users\Small\miniconda3\envs\sickit-env\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'non'

# %%
model.predict(X_transformed)
# Out:
# array([140550.54001554])
